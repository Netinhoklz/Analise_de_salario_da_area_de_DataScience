# %% [markdown]
# # Tratabalho de Engenharia de Dados II
#
# ## Equipe
# * José Freitas Alves Neto
# * Lia Santos
# * Lucas do Vale Pimentel

# %% [markdown]
# # Dataset: Análise de Salários em na área de Ciência de Dados
# ## Visão Geral
# Este dataset apresenta uma compilação abrangente de dados sobre salários e condições de trabalho no campo da ciência de dados. Reunindo informações anônimas de diversas fontes confiáveis, incluindo pesquisas de mercado e anúncios de vagas, o conjunto de dados oferece uma perspectiva única sobre as tendências do mercado de trabalho neste setor.
# ## Principais Características
#
# * **Abrangência Temporal:** Dados coletados ao longo de diferentes anos
# * **Padronização Monetária:** Salários convertidos para dólares americanos
# * **Diversidade Geográfica:** Informações de diferentes países e regiões
# * **Modalidades de Trabalho:** Inclui dados sobre trabalho remoto e presencial
# * **Perfis Profissionais:** Diversos níveis de experiência e cargos
#
# ## Relevância
# O dataset permite análises cruciais para:
#
# * Compreensão das tendências salariais globais
# * Avaliação do impacto da experiência na remuneração
# * Análise da influência do porte da empresa nos salários
# * Estudo das diferenças regionais nas compensações
# * Entendimento das políticas de trabalho remoto
#
# Este conjunto de dados serve como uma ferramenta valiosa para profissionais, empresas e pesquisadores interessados em compreender e analisar o mercado de trabalho em ciência de dados.

# %%
from pyspark.sql import SparkSession
import plotly.express as px
from pyspark.sql import functions as F

# !gdown 1tGyRG3vAEp4cz3ahV0XO80iFmBMZG4FD


spark = SparkSession.builder \
    .appName("Dataset salários") \
    .getOrCreate()


df = spark.read.csv('DataScience_salaries_2024.csv', header=True, inferSchema=True)
df.show()
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1tGyRG3vAEp4cz3ahV0XO80iFmBMZG4FD
# To: /content/DataScience_salaries_2024.csv
# 100% 851k/851k [00:00<00:00, 120MB/s]
# +---------+----------------+---------------+--------------------+--------+---------------+-------------+------------------+------------+----------------+------------+
# |work_year|experience_level|employment_type|           job_title|  salary|salary_currency|salary_in_usd|employee_residence|remote_ratio|company_location|company_size|
# +---------+----------------+---------------+--------------------+--------+---------------+-------------+------------------+------------+----------------+------------+
# |     2021|              MI|             FT|      Data Scientist|30400000|            CLP|        40038|                CL|         100|              CL|           L|
# |     2021|              MI|             FT|     BI Data Analyst|11000000|            HUF|        36259|                HU|          50|              US|           L|
# |     2020|              MI|             FT|      Data Scientist|11000000|            HUF|        35735|                HU|          50|              HU|           L|
# |     2021|              MI|             FT|         ML Engineer| 8500000|            JPY|        77364|                JP|          50|              JP|           S|
# |     2022|              SE|             FT|Lead Machine Lear...| 7500000|            INR|        95386|                IN|          50|              IN|           L|
# |     2021|              MI|             FT|         ML Engineer| 7000000|            JPY|        63711|                JP|          50|              JP|           S|
# |     2021|              SE|             FT|Data Science Manager| 7000000|            INR|        94665|                IN|          50|              IN|           L|
# |     2022|              EN|             FT|      Data Scientist| 6600000|            HUF|        17684|                HU|         100|              HU|           M|
# |     2022|              EX|             FT|Head of Machine L...| 6000000|            INR|        76309|                IN|          50|              IN|           L|
# |     2022|              EN|             FT|   Research Engineer| 5500000|            JPY|        41809|                JP|          50|              JP|           L|
# |     2023|              MI|             FT|Head of Data Science| 5000000|            INR|        60805|                IN|          50|              IN|           L|
# |     2023|              EN|             FT|       AI Programmer| 4950806|            INR|        60207|                IN|           0|              IN|           S|
# |     2021|              SE|             FT|Machine Learning ...| 4900000|            INR|        66265|                IN|           0|              IN|           L|
# |     2022|              SE|             FT| Lead Data Scientist| 4460000|            INR|        56723|                IN|           0|              IN|           L|
# |     2020|              EN|             FT|       Data Engineer| 4450000|            JPY|        41689|                JP|         100|              JP|           S|
# |     2022|              MI|             FT|      Data Scientist| 4200000|            INR|        53416|                IN|         100|              ID|           L|
# |     2023|              EN|             FT|Applied Machine L...| 4000000|            INR|        48644|                IN|         100|              DE|           L|
# |     2021|              SE|             FT|      Data Scientist| 4000000|            INR|        54094|                IN|         100|              IN|           L|
# |     2021|              SE|             FT|Data Science Manager| 4000000|            INR|        54094|                IN|          50|              US|           L|
# |     2023|              SE|             FT|Data Science Manager| 3600000|            INR|        43779|                IN|         100|              IN|           L|
# +---------+----------------+---------------+--------------------+--------+---------------+-------------+------------------+------------+----------------+------------+
# only showing top 20 rows

# %% [markdown]
# # Analisando o dataset

# %% [markdown]
# ## Analisando média salarial anual

# %% [markdown]
# ### Análise geral

# %%
resultado = df.groupBy("company_location").mean('salary_in_usd')
resultado = resultado.select(["company_location","avg(salary_in_usd)"]).orderBy(F.desc("avg(salary_in_usd)"))
df_rounded = resultado.withColumn("Salário médio", F.round("avg(salary_in_usd)", 2))
df_rounded.select(['company_location','Salário médio']).show()
# Out:
# +----------------+-------------+
# |company_location|Salário médio|
# +----------------+-------------+
# |              QA|     300000.0|
# |              IL|     217332.0|
# |              PR|     167500.0|
# |              US|    157410.13|
# |              NZ|    147681.67|
# |              CA|    145174.99|
# |              EG|    140869.23|
# |              SA|    139999.33|
# |              AU|    130126.47|
# |              MX|     129240.6|
# |              CH|    124646.89|
# |              JP|    110821.63|
# |              UA|     105600.0|
# |              IE|    104694.92|
# |              DZ|     100000.0|
# |              CN|     100000.0|
# |              IQ|     100000.0|
# |              IR|     100000.0|
# |              MU|     100000.0|
# |              SE|     98791.33|
# +----------------+-------------+
# only showing top 20 rows

# %% [markdown]
# ### Análise do salário médio do ano de 2024

# %%
df_filtered = df.filter(df["work_year"].startswith("2024"))
resultado = df_filtered.groupBy("company_location").mean('salary_in_usd')
resultado = resultado.select(["company_location","avg(salary_in_usd)"]).orderBy(F.desc("avg(salary_in_usd)"))
df_rounded = resultado.withColumn("Salário médio", F.round("avg(salary_in_usd)", 2))
df_rounded.select(['company_location','Salário médio']).show()
# Out:
# +----------------+-------------+
# |company_location|Salário médio|
# +----------------+-------------+
# |              MX|     223774.5|
# |              CH|     196401.0|
# |              US|    157129.54|
# |              EG|    150708.33|
# |              SA|     150000.0|
# |              CA|    147235.77|
# |              NZ|     143729.0|
# |              PL|    135444.25|
# |              AU|    133389.57|
# |              FR|    113459.36|
# |              IE|      93611.0|
# |              DE|      92852.6|
# |              AR|      88500.0|
# |              UA|      82000.0|
# |              GB|     78993.84|
# |              NL|      78091.0|
# |              FI|      77777.0|
# |              ES|     72184.67|
# |              LB|      71750.0|
# |              AE|      65000.0|
# +----------------+-------------+
# only showing top 20 rows

# %% [markdown]
# ### Salário médio do Brasil anualmente

# %%
df_filtered = df.filter(df["company_location"].startswith("BR"))
resultado = df_filtered.groupBy("work_year").mean('salary_in_usd')
resultado = resultado.select(["work_year","avg(salary_in_usd)"]).orderBy(F.desc("work_year"))
df_rounded = resultado.withColumn("Salário médio", F.round("avg(salary_in_usd)", 2))
df_rounded.select(['work_year','Salário médio']).show()
# Out:
# +---------+-------------+
# |work_year|Salário médio|
# +---------+-------------+
# |     2024|      46000.0|
# |     2023|     63252.57|
# |     2022|      63750.0|
# |     2021|      21453.5|
# +---------+-------------+

# %% [markdown]
# ### Analisando a média salariu entre trabalho remoto, presencial e hibrido

# %%
resultado = df.groupBy("remote_ratio").mean('salary_in_usd')
resultado = resultado.select(["remote_ratio","avg(salary_in_usd)"]).orderBy(F.desc("remote_ratio"))
df_rounded = resultado.withColumn("Salário médio", F.round("avg(salary_in_usd)", 2))
df_rounded.select(['remote_ratio','Salário médio']).show()
# Out:
# +------------+-------------+
# |remote_ratio|Salário médio|
# +------------+-------------+
# |         100|    145109.56|
# |          50|     83056.98|
# |           0|    153847.45|
# +------------+-------------+

# %% [markdown]
# ### Média salarial por título de trabalho

# %%
resultado = df.groupBy("job_title").mean('salary_in_usd')
resultado = resultado.select(["job_title","avg(salary_in_usd)"]).orderBy(F.desc("avg(salary_in_usd)"))
df_rounded = resultado.withColumn("Salário médio", F.round("avg(salary_in_usd)", 2))
df_rounded.select(['job_title','Salário médio']).show(truncate = False)
# Out:
# +------------------------------+-------------+
# |job_title                     |Salário médio|
# +------------------------------+-------------+
# |Analytics Engineering Manager |399880.0     |
# |Data Science Tech Lead        |375000.0     |
# |Head of Machine Learning      |299758.43    |
# |Managing Director Data Science|280000.0     |
# |AWS Data Architect            |258000.0     |
# |AI Architect                  |255142.36    |
# |Cloud Data Architect          |250000.0     |
# |Director of Data Science      |218775.33    |
# |Head of Data                  |210013.71    |
# |Data Infrastructure Engineer  |207332.81    |
# |Prompt Engineer               |205093.59    |
# |Data Analytics Lead           |198241.94    |
# |ML Engineer                   |197496.71    |
# |Robotics Software Engineer    |196625.0     |
# |Research Scientist            |194217.12    |
# |Principal Data Scientist      |194089.6     |
# |Machine Learning Scientist    |192214.06    |
# |Data Science Manager          |191612.11    |
# |Deep Learning Engineer        |190807.5     |
# |Computational Biologist       |190384.25    |
# +------------------------------+-------------+
# only showing top 20 rows

# %% [markdown]
# ### Média salarial com base no grau de experiência

# %%
resultado = df.groupBy("experience_level").mean('salary_in_usd')
resultado = resultado.select(["experience_level","avg(salary_in_usd)"]).orderBy(F.desc("avg(salary_in_usd)"))
df_rounded = resultado.withColumn("Salário médio", F.round("avg(salary_in_usd)", 2))
df_rounded.select(['experience_level','Salário médio']).show(truncate = False)
# Out:
# +----------------+-------------+
# |experience_level|Salário médio|
# +----------------+-------------+
# |EX              |194730.21    |
# |SE              |163700.97    |
# |MI              |125386.55    |
# |EN              |91656.84     |
# +----------------+-------------+

# %% [markdown]
# ## Gerando gráficos
# Puxando todos os dados para criar gráficos

# %%
df_pandas = df.toPandas()

# %% [markdown]
# ### Criando histograma do salário anualizado

# %%
histograma = px.histogram(data_frame = df_pandas, x = 'salary_in_usd', facet_col='work_year', category_orders={'work_year': [2020,2021,2022,2023,2024]}, barmode='overlay', nbins=100, title='Salário anualizado',
                          labels = {'work_year':'Ano','count':'Frequência','salary_in_usd':'Salário dolarizado'})
histograma.update_layout(
    title_x=0.5,  # Centralizar o título
    bargap=0.2,  # Ajuste do espaço entre as barras para melhor visualização
    template='plotly_white'  # Tema branco para uma aparência mais limpa
)
histograma.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="2f1e2374-4554-4789-a802-88bce2732e2a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2f1e2374-4554-4789-a802-88bce2732e2a")) {                    Plotly.newPlot(                        "2f1e2374-4554-4789-a802-88bce2732e2a",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Ano=2020\u003cbr\u003eSal\u00e1rio dolarizado=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","opacity":0.5,"pattern":{"shape":""}},"name":"","nbinsx":100,"offsetgroup":"","orientation":"v","showlegend":false,"x":[35735,41689,40481,33511,450000,412000,325000,300000,45896,260000,250000,190200,190000,188000,164000,117104,150000,138350,138000,135000,130800,148261,125000,120000,118000,115000,110000,106000,105000,105000,103000,100000,114047,100000,98000,95000,91000,112872,87000,109024,85000,91237,72000,70000,79833,79833,74130,70139,44753,60000,68428,76958,60000,56000,62726,62726,59303,54742,45760,51321,50180,49268,47899,42000,47899,46759,45618,42197,39916,38776,22809,20000,21669,15000,15966],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Ano=2021\u003cbr\u003eSal\u00e1rio dolarizado=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","opacity":0.5,"pattern":{"shape":""}},"name":"","nbinsx":100,"offsetgroup":"","orientation":"v","showlegend":false,"x":[40038,36259,77364,63711,94665,66265,54094,54094,40570,33808,30428,29751,28399,24342,22611,21637,19609,18053,16904,16904,16228,423000,416000,276000,270000,256000,250000,250000,28016,240000,235000,187442,235000,230000,225000,225000,220000,200000,200000,200000,200000,200000,200000,195000,185000,185000,185000,180000,20171,46597,28609,174000,174000,170000,170000,170000,168000,165000,165000,165000,160000,160000,160000,119059,127221,153000,152000,151000,150000,150000,150000,150000,150000,150000,150000,147000,173762,144000,140000,140000,135000,135000,153667,103691,130000,125000,99703,96113,19073,120000,120000,89294,141846,120000,115000,115000,115000,112000,111775,130026,28476,110000,110000,110000,87738,109000,105000,18907,75050,100000,100000,100000,100000,100000,100000,75774,93150,93000,66970,90000,90000,90000,90000,71786,90000,102839,85000,85000,116914,82500,113476,95746,81000,80000,110037,80000,80000,80000,94564,80000,63810,90734,90734,88654,103160,88654,88654,75000,74000,73000,72500,82744,70000,96282,69999,54238,79197,77684,76833,76833,76833,62000,60000,60000,82528,60000,82528,69741,69741,58000,56000,42028,55000,55000,65013,63831,63831,62649,72212,61467,60757,50000,50000,50000,59102,50000,50000,59102,66022,56738,45555,53192,61896,51064,49646,56256,47282,46809,38400,45391,51519,40189,45390,37825,36643,30000,24000,28369,26005,21844,25532,24823,24823,20000,20000,20000,18000,15000],"xaxis":"x2","yaxis":"y2","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Ano=2022\u003cbr\u003eSal\u00e1rio dolarizado=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","opacity":0.5,"pattern":{"shape":""}},"name":"","nbinsx":100,"offsetgroup":"","orientation":"v","showlegend":false,"x":[95386,17684,76309,41809,56723,53416,38154,35610,31795,30523,30523,22892,20984,18314,17805,17805,15897,405000,380000,375000,375000,430967,350000,345600,324000,315000,310000,310000,300000,300000,300000,300000,300000,300000,299500,297500,275000,275000,272550,266400,260500,260000,260000,260000,260000,255000,250000,250000,250000,250000,250000,250000,250000,250000,250000,250000,250000,250000,250000,250000,250000,192037,249500,249500,249500,249260,248700,24 ...

# %% [markdown]
# # Distribuição salarial por nível de experiência

# %%
box_plot = px.box(
    df_pandas,
    x='experience_level',
    y='salary_in_usd',
    title='Distribuição salarial por experiência',
    labels={'salary_in_usd': 'Salário Anual', 'experience_level': 'Grau de experiência'},
    height= 600,
    width= 600
)
box_plot.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="e35d969b-c013-43b1-8a03-4f73ee923141" class="plotly-graph-div" style="height:600px; width:600px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e35d969b-c013-43b1-8a03-4f73ee923141")) {                    Plotly.newPlot(                        "e35d969b-c013-43b1-8a03-4f73ee923141",                        [{"alignmentgroup":"True","hovertemplate":"Grau de experi\u00eancia=%{x}\u003cbr\u003eSal\u00e1rio Anual=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x":["MI","MI","MI","MI","SE","MI","SE","EN","EX","EN","MI","EN","SE","SE","EN","MI","EN","SE","SE","SE","MI","MI","MI","SE","SE","SE","MI","MI","MI","MI","MI","MI","MI","MI","EN","EN","EN","EN","MI","EN","SE","EN","MI","MI","MI","EN","SE","MI","MI","MI","MI","EN","MI","MI","EN","MI","EN","SE","MI","MI","MI","EN","EX","SE","MI","MI","MI","SE","EN","SE","MI","SE","MI","MI","MI","MI","SE","MI","SE","MI","SE","SE","MI","MI","MI","SE","SE","MI","MI","SE","SE","SE","SE","SE","MI","MI","SE","SE","SE","EX","SE","MI","SE","EX","MI","MI","MI","MI","SE","MI","MI","SE","MI","MI","SE","SE","SE","SE","EX","MI","SE","SE","EX","SE","SE","SE","SE","EX","MI","SE","SE","MI","SE","SE","SE","SE","MI","SE","SE","MI","EX","SE","SE","SE","SE","SE","SE","SE","SE","EX","SE","SE","SE","EX","SE","SE","SE","EX","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","MI","SE","SE","MI","MI","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","EX","EX","SE","EN","EX","SE","SE","MI","SE","MI","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","MI","SE","SE","SE","SE","SE","EX","SE","EX","SE","SE","SE","SE","SE","SE","EX","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","EX","SE","SE","SE","SE","SE","SE","EX","SE","EX","EX","EX","EX","SE","SE","SE","MI","SE","EX","MI","SE","SE","EX","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","EX","EX","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","MI","SE","SE","EX","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","EX","EX","SE","SE","EX","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","MI","MI","SE","SE","SE","EX","EX","EX","EX","SE","EX","EX","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","MI","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","EX","SE","MI","EN","EN","EN","EX","EX","SE","EX","SE","SE","SE","EX","SE","SE","SE","SE","SE","SE","SE","SE","SE","MI","SE","SE","MI","MI","SE","MI","MI","SE","SE","SE","SE","MI","MI","MI","MI","MI","SE","SE","SE","SE","MI","EX","MI","SE","MI","SE","SE","EX","SE","SE","SE","SE","SE","SE","EN","SE","SE","EX","SE","SE","SE","SE","SE","SE","SE","SE","SE","EX","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","MI","SE","SE","SE","SE","SE","SE","EX","SE","SE","SE","SE","SE","SE","SE","SE","MI","MI","SE","MI","MI","MI","MI","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","EN","SE","SE","SE","SE","SE","EX","SE","SE","SE","EX","SE","SE","EX","SE","SE","SE","SE","SE","SE","SE","SE","SE","EX","SE","SE","SE","SE","MI","MI","SE","SE","SE","SE","SE","SE","MI","MI","EX","SE","SE","EX","SE","SE","SE","SE","SE","MI","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","EX","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","EN","SE","SE","SE","SE","SE","SE" ...

# %% [markdown]
# ## Média salarial ao longo dos anos

# %%
df_filtered = df.filter(df["company_location"].startswith("BR"))
resultado = df_filtered.groupBy("work_year").mean('salary_in_usd')
resultado = resultado.select(["work_year","avg(salary_in_usd)"]).orderBy(F.desc("work_year"))
df_rounded = resultado.withColumn("Salário médio", F.round("avg(salary_in_usd)", 2))

scatter = px.line(data_frame = df_rounded, x = 'work_year', y = 'Salário médio', width=500, height=500)
scatter.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="60d3ddf8-7eab-4e88-b691-963818f3d7f0" class="plotly-graph-div" style="height:500px; width:500px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("60d3ddf8-7eab-4e88-b691-963818f3d7f0")) {                    Plotly.newPlot(                        "60d3ddf8-7eab-4e88-b691-963818f3d7f0",                        [{"hovertemplate":"work_year=%{x}\u003cbr\u003eSal\u00e1rio m\u00e9dio=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":[2024,2023,2022,2021],"xaxis":"x","y":[46000.0,63252.57,63750.0,21453.5],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks": ...

# %% [markdown]
# ## Paises com os maiores salários

# %%
resultado = df.groupBy("company_location").mean('salary_in_usd')
resultado = resultado.select(["company_location","avg(salary_in_usd)"]).orderBy(F.desc("avg(salary_in_usd)"))
df_rounded = resultado.withColumn("Salário médio", F.round("avg(salary_in_usd)", 2))


hist_ = px.bar(data_frame = df_rounded, x = 'company_location', y ='Salário médio', title ='Salário médio por país', labels = {'company_location':'País'})
hist_.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="4275bb37-387b-4941-b3f6-69959a9d63d0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4275bb37-387b-4941-b3f6-69959a9d63d0")) {                    Plotly.newPlot(                        "4275bb37-387b-4941-b3f6-69959a9d63d0",                        [{"alignmentgroup":"True","hovertemplate":"Pa\u00eds=%{x}\u003cbr\u003eSal\u00e1rio m\u00e9dio=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["QA","IL","PR","US","NZ","CA","EG","SA","AU","MX","CH","JP","UA","IE","DZ","CN","IQ","IR","MU","SE","GB","DE","NO","FR","AE","PL","GI","CO","RU","BE","HR","NL","BA","LB","FI","AR","CZ","LT","AT","HK","KE","VN","SG","NG","ES","SI","BR","ZA","LV","GR","AD","MT","PT","AM","IT","DK","CF","PH","LU","KR","OM","EE","BS","RO","IN","CL","MY","HU","ID","AS","PK","GH","TR","TH","HN","MD","EC"],"xaxis":"x","y":[300000.0,217332.0,167500.0,157410.13,147681.67,145174.99,140869.23,139999.33,130126.47,129240.6,124646.89,110821.63,105600.0,104694.92,100000.0,100000.0,100000.0,100000.0,100000.0,98791.33,95321.22,92163.96,88462.0,86310.51,86000.0,83083.36,79976.0,79115.25,78207.86,76864.75,76726.0,76171.82,75000.0,71750.0,70833.75,69571.43,69478.67,68553.06,68479.3,65058.0,65000.0,63000.0,62783.0,60444.44,56817.15,56186.33,56175.0,55786.53,54734.93,52260.86,50745.0,50423.0,50253.89,50000.0,49600.43,49402.6,49216.0,49046.67,47609.33,47000.0,46848.0,45588.42,45555.0,44713.0,41995.42,40038.0,40000.0,39938.0,34208.0,31684.33,30000.0,27000.0,23094.67,22971.33,20000.0,18000.0,16000.0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888 ...

# %% [markdown]
# # Adicionando o Dataset padrão ao MongoDB

# %% [markdown]
# ## Importando bibliotecas e fazendo a instalação

# %%
# !pip install pymongo==3.10.0
# Out:
# Requirement already satisfied: pymongo==3.10.0 in /usr/local/lib/python3.10/dist-packages (3.10.0)

# %%
import pymongo

# %%
# !wget https://fastdl.mongodb.org/linux/mongodb-linux-x86_64-3.0.15.tgz
# !tar xfv /content/mongodb-linux-x86_64-3.0.15.tgz
# Out:
# --2024-10-27 13:25:49--  https://fastdl.mongodb.org/linux/mongodb-linux-x86_64-3.0.15.tgz
# Resolving fastdl.mongodb.org (fastdl.mongodb.org)... 3.167.99.33, 3.167.99.83, 3.167.99.110, ...
# Connecting to fastdl.mongodb.org (fastdl.mongodb.org)|3.167.99.33|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 63276568 (60M) [application/x-gzip]
# Saving to: ‘mongodb-linux-x86_64-3.0.15.tgz’
#
# mongodb-linux-x86_6 100%[===================>]  60.34M   172MB/s    in 0.4s
#
# 2024-10-27 13:25:50 (172 MB/s) - ‘mongodb-linux-x86_64-3.0.15.tgz’ saved [63276568/63276568]
#
# mongodb-linux-x86_64-3.0.15/README
# mongodb-linux-x86_64-3.0.15/THIRD-PARTY-NOTICES
# mongodb-linux-x86_64-3.0.15/GNU-AGPL-3.0
# mongodb-linux-x86_64-3.0.15/bin/mongodump
# mongodb-linux-x86_64-3.0.15/bin/mongorestore
# mongodb-linux-x86_64-3.0.15/bin/mongoexport
# mongodb-linux-x86_64-3.0.15/bin/mongoimport
# mongodb-linux-x86_64-3.0.15/bin/mongostat
# mongodb-linux-x86_64-3.0.15/bin/mongotop
# mongodb-linux-x86_64-3.0.15/bin/bsondump
# mongodb-linux-x86_64-3.0.15/bin/mongofiles
# mongodb-linux-x86_64-3.0.15/bin/mongooplog
# mongodb-linux-x86_64-3.0.15/bin/mongoperf
# mongodb-linux-x86_64-3.0.15/bin/mongod
# mongodb-linux-x86_64-3.0.15/bin/mongos
# mongodb-linux-x86_64-3.0.15/bin/mongo

# %%
# !mkdir /data                                          # data folder creation
# !mkdir /data/db
# Out:
# mkdir: cannot create directory ‘/data’: File exists
# mkdir: cannot create directory ‘/data/db’: File exists

# %%
# !nohup sudo /content/mongodb-linux-x86_64-3.0.15/bin/mongod --nojournal --dbpath /data/db >log1 &
# Out:
# nohup: redirecting stderr to stdout

# %%
# !cat log1
# Out:
# 2024-10-27T13:25:54.000+0000 I CONTROL  [initandlisten] MongoDB starting : pid=4543 port=27017 dbpath=/data/db 64-bit host=8bbf707053ca
# 2024-10-27T13:25:54.004+0000 I CONTROL  [initandlisten] db version v3.0.15
# 2024-10-27T13:25:54.005+0000 I CONTROL  [initandlisten] git version: b8ff507269c382bc100fc52f75f48d54cd42ec3b
# 2024-10-27T13:25:54.005+0000 I CONTROL  [initandlisten] build info: Linux ip-10-142-230-168 2.6.18-194.el5xen #1 SMP Tue Mar 16 22:01:26 EDT 2010 x86_64 BOOST_LIB_VERSION=1_49
# 2024-10-27T13:25:54.005+0000 I CONTROL  [initandlisten] allocator: tcmalloc
# 2024-10-27T13:25:54.005+0000 I CONTROL  [initandlisten] options: { storage: { dbPath: "/data/db", journal: { enabled: false } } }

# %%
# !mongodb-linux-x86_64-3.0.15/bin/mongod
# Out:
# 2024-10-27T13:25:54.270+0000 I CONTROL  [initandlisten] MongoDB starting : pid=4548 port=27017 dbpath=/data/db 64-bit host=8bbf707053ca
# 2024-10-27T13:25:54.270+0000 I CONTROL  [initandlisten] db version v3.0.15
# 2024-10-27T13:25:54.270+0000 I CONTROL  [initandlisten] git version: b8ff507269c382bc100fc52f75f48d54cd42ec3b
# 2024-10-27T13:25:54.270+0000 I CONTROL  [initandlisten] build info: Linux ip-10-142-230-168 2.6.18-194.el5xen #1 SMP Tue Mar 16 22:01:26 EDT 2010 x86_64 BOOST_LIB_VERSION=1_49
# 2024-10-27T13:25:54.274+0000 I CONTROL  [initandlisten] allocator: tcmalloc
# 2024-10-27T13:25:54.274+0000 I CONTROL  [initandlisten] options: {}
# 2024-10-27T13:25:54.280+0000 W -        [initandlisten] Detected unclean shutdown - /data/db/mongod.lock is not empty.
# 2024-10-27T13:25:54.305+0000 I STORAGE  [initandlisten] exception in initAndListen: 98 Unable to lock file: /data/db/mongod.lock errno:11 Resource temporarily unavailable. Is a mongod instance already running?, terminating
# 2024-10-27T13:25:54.305+0000 I CONTROL  [initandlisten] dbexit:  rc: 100

# %%
from pymongo import MongoClient
client = MongoClient('127.0.0.1', 27017)

db = client['Meus_Data_sets']
colecao = db['salario_cientistas_de_dados']

data = df_pandas.to_dict(orient='records')

colecao.insert_many(data)

print("DataFrame salvo no MongoDB com sucesso!")
# Out:
# DataFrame salvo no MongoDB com sucesso!

# %%
todos_documentos = colecao.find()
for documento in todos_documentos:
    print(documento)
# Out:
# A saída de streaming foi truncada nas últimas 5000 linhas.
# {'_id': ObjectId('671e402d1c2b687bc66225fc'), 'work_year': 2022, 'experience_level': 'SE', 'employment_type': 'FT', 'job_title': 'Data Analyst', 'salary': 119000, 'salary_currency': 'USD', 'salary_in_usd': 119000, 'employee_residence': 'US', 'remote_ratio': 100, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc66225fd'), 'work_year': 2022, 'experience_level': 'SE', 'employment_type': 'FT', 'job_title': 'Data Analyst', 'salary': 119000, 'salary_currency': 'USD', 'salary_in_usd': 119000, 'employee_residence': 'US', 'remote_ratio': 0, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc66225fe'), 'work_year': 2022, 'experience_level': 'SE', 'employment_type': 'FT', 'job_title': 'Machine Learning Engineer', 'salary': 119000, 'salary_currency': 'USD', 'salary_in_usd': 119000, 'employee_residence': 'US', 'remote_ratio': 0, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc66225ff'), 'work_year': 2022, 'experience_level': 'SE', 'employment_type': 'FT', 'job_title': 'Data Analyst', 'salary': 119000, 'salary_currency': 'USD', 'salary_in_usd': 119000, 'employee_residence': 'US', 'remote_ratio': 0, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc6622600'), 'work_year': 2023, 'experience_level': 'SE', 'employment_type': 'FT', 'job_title': 'Data Scientist', 'salary': 118900, 'salary_currency': 'USD', 'salary_in_usd': 118900, 'employee_residence': 'US', 'remote_ratio': 0, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc6622601'), 'work_year': 2023, 'experience_level': 'MI', 'employment_type': 'FT', 'job_title': 'Research Scientist', 'salary': 118800, 'salary_currency': 'USD', 'salary_in_usd': 118800, 'employee_residence': 'US', 'remote_ratio': 100, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc6622602'), 'work_year': 2023, 'experience_level': 'MI', 'employment_type': 'FT', 'job_title': 'Research Scientist', 'salary': 118800, 'salary_currency': 'USD', 'salary_in_usd': 118800, 'employee_residence': 'US', 'remote_ratio': 100, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc6622603'), 'work_year': 2023, 'experience_level': 'SE', 'employment_type': 'FT', 'job_title': 'BI Analyst', 'salary': 118800, 'salary_currency': 'USD', 'salary_in_usd': 118800, 'employee_residence': 'US', 'remote_ratio': 100, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc6622604'), 'work_year': 2023, 'experience_level': 'SE', 'employment_type': 'FT', 'job_title': 'BI Analyst', 'salary': 118800, 'salary_currency': 'USD', 'salary_in_usd': 118800, 'employee_residence': 'US', 'remote_ratio': 100, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc6622605'), 'work_year': 2024, 'experience_level': 'EN', 'employment_type': 'FT', 'job_title': 'Data Analyst', 'salary': 118750, 'salary_currency': 'USD', 'salary_in_usd': 118750, 'employee_residence': 'US', 'remote_ratio': 0, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc6622606'), 'work_year': 2023, 'experience_level': 'EN', 'employment_type': 'FT', 'job_title': 'Data Analyst', 'salary': 118750, 'salary_currency': 'USD', 'salary_in_usd': 118750, 'employee_residence': 'US', 'remote_ratio': 0, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc6622607'), 'work_year': 2023, 'experience_level': 'SE', 'employment_type': 'FT', 'job_title': 'Data Scientist', 'salary': 118720, 'salary_currency': 'USD', 'salary_in_usd': 118720, 'employee_residence': 'US', 'remote_ratio': 100, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc6622608'), 'work_year': 2024, 'experience_level': 'MI', 'employment_type': 'FT', 'job_title': 'Research Engineer', 'salary': 118600, 'salary_currency': 'USD', 'salary_in_usd': 118600, 'employee_residence': 'US', 'remote_ratio': 0, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc6622609'), 'work_year': 2023, 'experience_level': 'SE', 'employment_type': 'FT', 'job_title': 'Data Analyst', 'salary': 118600, 'salary_currency': 'USD', 'salary_in_usd': 118600, 'employee_residence': 'US', 'remote_ratio': 0, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc662260a'), 'work_year': 2023, 'experience_level': 'SE', 'employment_type': 'FT', 'job_title': 'Data Engineer', 'salary': 118575, 'salary_currency': 'USD', 'salary_in_usd': 118575, 'employee_residence': 'US', 'remote_ratio': 100, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc662260b'), 'work_year': 2023, 'experience_level': 'SE', 'employment_type': 'FT', 'job_title': 'Data Scientist', 'salary': 118575, 'salary_currency': 'USD', 'salary_in_usd': 118575, 'employee_residence': 'CA', 'remote_ratio': 100, 'company_location': 'CA', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc662260c'), 'work_year': 2024, 'experience_level': 'SE', 'employment_type': 'FT', 'job_title': 'Machine Learning Engineer', 'salary': 118500, 'salary_currency': 'USD', 'salary_in_usd': 118500, 'employee_residence': 'US', 'remote_ratio': 100, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc662260d'), 'work_year': 2023, 'experience_level': 'SE', 'employment_type': 'FT', 'job_title': 'Applied Scientist', 'salary': 118500, 'salary_currency': 'USD', 'salary_in_usd': 118500, 'employee_residence': 'US', 'remote_ratio': 0, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc662260e'), 'work_year': 2023, 'experience_level': 'EX', 'employment_type': 'FT', 'job_title': 'Director of Data Science', 'salary': 118440, 'salary_currency': 'USD', 'salary_in_usd': 118440, 'employee_residence': 'US', 'remote_ratio': 100, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc662260f'), 'work_year': 2024, 'experience_level': 'MI', 'employment_type': 'FT', 'job_title': 'Data Engineer', 'salary': 118400, 'salary_currency': 'USD', 'salary_in_usd': 118400, 'employee_residence': 'US', 'remote_ratio': 0, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc6622610'), 'work_year': 2023, 'experience_level': 'SE', 'employment_type': 'FT', 'job_title': 'Research Scientist', 'salary': 118400, 'salary_currency': 'USD', 'salary_in_usd': 118400, 'employee_residence': 'US', 'remote_ratio': 0, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc6622611'), 'work_year': 2024, 'experience_level': 'MI', 'employment_type': 'FT', 'job_title': 'Data Engineer', 'salary': 118300, 'salary_currency': 'USD', 'salary_in_usd': 118300, 'employee_residence': 'CA', 'remote_ratio': 0, 'company_location': 'CA', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc6622612'), 'work_year': 2024, 'experience_level': 'SE', 'employment_type': 'FT', 'job_title': 'Data Engineer', 'salary': 118300, 'salary_currency': 'USD', 'salary_in_usd': 118300, 'employee_residence': 'US', 'remote_ratio': 0, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc6622613'), 'work_year': 2023, 'experience_level': 'SE', 'employment_type': 'FT', 'job_title': 'Business Intelligence Engineer', 'salary': 118200, 'salary_currency': 'USD', 'salary_in_usd': 118200, 'employee_residence': 'US', 'remote_ratio': 100, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc6622614'), 'work_year': 2024, 'experience_level': 'SE', 'employment_type': 'FT', 'job_title': 'Data Scientist', 'salary': 118136, 'salary_currency': 'USD', 'salary_in_usd': 118136, 'employee_residence': 'US', 'remote_ratio': 0, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc6622615'), 'work_year': 2023, 'experience_level': 'SE', 'employment_type': 'FT', 'job_title': 'Business Intelligence Analyst', 'salary': 118100, 'salary_currency': 'USD', 'salary_in_usd': 118100, 'employee_residence': 'US', 'remote_ratio': 100, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc6622616'), 'work_year': 2023, 'experience_level': 'MI', 'employment_type': 'FT', 'job_title': 'Business Intelligence Analyst', 'salary': 118100, 'salary_currency': 'USD', 'salary_in_usd': 118100, 'employee_residence': 'US', 'remote_ratio': 100, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc6622617'), 'work_year': 2024, 'experience_level': 'EN', 'employment_type': 'FT', 'job_title': 'Data Analyst', 'salary': 118000, 'salary_currency': 'USD', 'salary_in_usd': 118000, 'employee_residence': 'US', 'remote_ratio': 0, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc6622618'), 'work_year': 2024, 'experience_level': 'MI', 'employment_type': 'FT', 'job_title': 'Data Analyst', 'salary': 118000, 'salary_currency': 'USD', 'salary_in_usd': 118000, 'employee_residence': 'US', 'remote_ratio': 0, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc6622619'), 'work_year': 2024, 'experience_level': 'SE', 'employment_type': 'FT', 'job_title': 'Data Engineer', 'salary': 118000, 'salary_currency': 'USD', 'salary_in_usd': 118000, 'employee_residence': 'US', 'remote_ratio': 0, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc662261a'), 'work_year': 2023, 'experience_level': 'SE', 'employment_type': 'FT', 'job_title': 'Data Scientist', 'salary': 118000, 'salary_currency': 'USD', 'salary_in_usd': 118000, 'employee_residence': 'US', 'remote_ratio': 100, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc662261b'), 'work_year': 2023, 'experience_level': 'SE', 'employment_type': 'FT', 'job_title': 'Data Analyst', 'salary': 118000, 'salary_currency': 'USD', 'salary_in_usd': 118000, 'employee_residence': 'US', 'remote_ratio': 100, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc662261c'), 'work_year': 2023, 'experience_level': 'SE', 'employment_type': 'FT', 'job_title': 'Data Engineer', 'salary': 118000, 'salary_currency': 'USD', 'salary_in_usd': 118000, 'employee_residence': 'US', 'remote_ratio': 0, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc662261d'), 'work_year': 2023, 'experience_level': 'SE', 'employment_type': 'FT', 'job_title': 'Data Analyst', 'salary': 118000, 'salary_currency': 'USD', 'salary_in_usd': 118000, 'employee_residence': 'US', 'remote_ratio': 100, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc662261e'), 'work_year': 2023, 'experience_level': 'SE', 'employment_type': 'FT', 'job_title': 'Data Analyst', 'salary': 118000, 'salary_currency': 'USD', 'salary_in_usd': 118000, 'employee_residence': 'US', 'remote_ratio': 100, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc662261f'), 'work_year': 2023, 'experience_level': 'SE', 'employment_type': 'FT', 'job_title': 'Data Scientist', 'salary': 118000, 'salary_currency': 'USD', 'salary_in_usd': 118000, 'employee_residence': 'US', 'remote_ratio': 0, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc6622620'), 'work_year': 2022, 'experience_level': 'MI', 'employment_type': 'FT', 'job_title': 'Data Engineer', 'salary': 118000, 'salary_currency': 'USD', 'salary_in_usd': 118000, 'employee_residence': 'US', 'remote_ratio': 100, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc6622621'), 'work_year': 2020, 'experience_level': 'MI', 'employment_type': 'FT', 'job_title': 'Data Scientist', 'salary': 118000, 'salary_currency': 'USD', 'salary_in_usd': 118000, 'employee_residence': 'US', 'remote_ratio': 100, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc6622622'), 'work_year': 2024, 'experience_level': 'SE', 'employment_type': 'FT', 'job_title': 'MLOps Engineer', 'salary': 117800, 'salary_currency': 'USD', 'salary_in_usd': 117800, 'employee_residence': 'US', 'remote_ratio': 0, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc6622623'), 'work_year': 2024, 'experience_level': 'MI', 'employment_type': 'FT', 'job_title': 'Business Intelligence Developer', 'salary': 117750, 'salary_currency': 'USD', 'salary_in_usd': 117750, 'employee_residence': 'US', 'remote_ratio': 0, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc6622624'), 'work_year': 2024, 'experience_level': 'SE', 'employment_type': 'FT', 'job_title': 'Data Analyst', 'salary': 117725, 'salary_currency': 'USD', 'salary_in_usd': 117725, 'employee_residence': 'US', 'remote_ratio': 100, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc6622625'), 'work_year': 2023, 'experience_level': 'SE', 'employment_type': 'FT', 'job_title': 'Analytics Engineer', 'salary': 117700, 'salary_currency': 'USD', 'salary_in_usd': 117700, 'employee_residence': 'GB', 'remote_ratio': 100, 'company_location': 'GB', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc6622626'), 'work_year': 2024, 'experience_level': 'MI', 'employment_type': 'FT', 'job_title': 'Business Intelligence Manager', 'salary': 117500, 'salary_currency': 'USD', 'salary_in_usd': 117500, 'employee_residence': 'US', 'remote_ratio': 0, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc6622627'), 'work_year': 2024, 'experience_level': 'EX', 'employment_type': 'FT', 'job_title': 'Business Intelligence Developer', 'salary': 117500, 'salary_currency': 'USD', 'salary_in_usd': 117500, 'employee_residence': 'US', 'remote_ratio': 0, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc6622628'), 'work_year': 2023, 'experience_level': 'SE', 'employment_type': 'FT', 'job_title': 'Data Analyst', 'salary': 117500, 'salary_currency': 'USD', 'salary_in_usd': 117500, 'employee_residence': 'US', 'remote_ratio': 100, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc6622629'), 'work_year': 2024, 'experience_level': 'MI', 'employment_type': 'FT', 'job_title': 'Analytics Engineer', 'salary': 117400, 'salary_currency': 'USD', 'salary_in_usd': 117400, 'employee_residence': 'US', 'remote_ratio': 0, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc662262a'), 'work_year': 2024, 'experience_level': 'SE', 'employment_type': 'FT', 'job_title': 'Data Scientist', 'salary': 117400, 'salary_currency': 'USD', 'salary_in_usd': 117400, 'employee_residence': 'US', 'remote_ratio': 0, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc662262b'), 'work_year': 2023, 'experience_level': 'MI', 'employment_type': 'FT', 'job_title': 'Data Engineer', 'salary': 117300, 'salary_currency': 'USD', 'salary_in_usd': 117300, 'employee_residence': 'US', 'remote_ratio': 0, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc662262c'), 'work_year': 2023, 'experience_level': 'SE', 'employment_type': 'FT', 'job_title': 'Analytics Engineer', 'salary': 117100, 'salary_currency': 'USD', 'salary_in_usd': 117100, 'employee_residence': 'US', 'remote_ratio': 100, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc662262d'), 'work_year': 2024, 'experience_level': 'MI', 'employment_type': 'FT', 'job_title': 'Data Scientist', 'salary': 117000, 'salary_currency': 'USD', 'salary_in_usd': 117000, 'employee_residence': 'US', 'remote_ratio': 100, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc662262e'), 'work_year': 2024, 'experience_level': 'MI', 'employment_type': 'FT', 'job_title': 'Data Analyst', 'salary': 117000, 'salary_currency': 'USD', 'salary_in_usd': 117000, 'employee_residence': 'US', 'remote_ratio': 0, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc662262f'), 'work_year': 2024, 'experience_level': 'SE', 'employment_type': 'FT', 'job_title': 'Data Analyst', 'salary': 117000, 'salary_currency': 'USD', 'salary_in_usd': 117000, 'employee_residence': 'US', 'remote_ratio': 0, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc6622630'), 'work_year': 2024, 'experience_level': 'SE', 'employment_type': 'FT', 'job_title': 'Data Architect', 'salary': 117000, 'salary_currency': 'USD', 'salary_in_usd': 117000, 'employee_residence': 'US', 'remote_ratio': 0, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc6622631'), 'work_year': 2024, 'experience_level': 'SE', 'employment_type': 'FT', 'job_title': 'Data Analyst', 'salary': 117000, 'salary_currency': 'USD', 'salary_in_usd': 117000, 'employee_residence': 'US', 'remote_ratio': 0, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc6622632'), 'work_year': 2024, 'experience_level': 'MI', 'employment_type': 'FT', 'job_title': 'Data Scientist', 'salary': 117000, 'salary_currency': 'USD', 'salary_in_usd': 117000, 'employee_residence': 'US', 'remote_ratio': 0, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc6622633'), 'work_year': 2024, 'experience_level': 'SE', 'employment_type': 'FT', 'job_title': 'Data Analyst', 'salary': 117000, 'salary_currency': 'USD', 'salary_in_usd': 117000, 'employee_residence': 'US', 'remote_ratio': 0, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc6622634'), 'work_year': 2024, 'experience_level': 'MI', 'employment_type': 'FT', 'job_title': 'Big Data Developer', 'salary': 117000, 'salary_currency': 'USD', 'salary_in_usd': 117000, 'employee_residence': 'US', 'remote_ratio': 0, 'company_location': 'US', 'company_size': 'L'}
# {'_id': ObjectId('671e402d1c2b687bc6622635'), 'work_year': 2024, 'experience_level': 'SE', 'employment_type': 'FT', 'job_title': 'Data Architect', 'salary': 117000, 'salary_currency': 'USD', 'salary_in_usd': 117000, 'employee_residence': 'US', 'remote_ratio': 0, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc6622636'), 'work_year': 2024, 'experience_level': 'SE', 'employment_type': 'FT', 'job_title': 'Data Architect', 'salary': 117000, 'salary_currency': 'USD', 'salary_in_usd': 117000, 'employee_residence': 'US', 'remote_ratio': 0, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc6622637'), 'work_year': 2024, 'experience_level': 'MI', 'employment_type': 'FT', 'job_title': 'Business Intelligence Manager', 'salary': 117000, 'salary_currency': 'USD', 'salary_in_usd': 117000, 'employee_residence': 'US', 'remote_ratio': 0, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc6622638'), 'work_year': 2024, 'experience_level': 'SE', 'employment_type': 'FT', 'job_title': 'Data Architect', 'salary': 117000, 'salary_currency': 'USD', 'salary_in_usd': 117000, 'employee_residence': 'US', 'remote_ratio': 0, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc6622639'), 'work_year': 2024, 'experience_level': 'SE', 'employment_type': 'FT', 'job_title': 'Data Engineer', 'salary': 117000, 'salary_currency': 'USD', 'salary_in_usd': 117000, 'employee_residence': 'US', 'remote_ratio': 0, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc662263a'), 'work_year': 2024, 'experience_level': 'MI', 'employment_type': 'FT', 'job_title': 'Machine Learning Scientist', 'salary': 117000, 'salary_currency': 'USD', 'salary_in_usd': 117000, 'employee_residence': 'CA', 'remote_ratio': 100, 'company_location': 'CA', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc662263b'), 'work_year': 2024, 'experience_level': 'SE', 'employment_type': 'FT', 'job_title': 'Data Architect', 'salary': 117000, 'salary_currency': 'USD', 'salary_in_usd': 117000, 'employee_residence': 'US', 'remote_ratio': 0, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc662263c'), 'work_year': 2024, 'experience_level': 'MI', 'employment_type': 'FT', 'job_title': 'Data Engineer', 'salary': 117000, 'salary_currency': 'EUR', 'salary_in_usd': 130000, 'employee_residence': 'DE', 'remote_ratio': 0, 'company_location': 'DE', 'company_size': 'L'}
# {'_id': ObjectId('671e402d1c2b687bc662263d'), 'work_year': 2024, 'experience_level': 'SE', 'employment_type': 'FT', 'job_title': 'Data Analyst', 'salary': 117000, 'salary_currency': 'USD', 'salary_in_usd': 117000, 'employee_residence': 'US', 'remote_ratio': 0, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc662263e'), 'work_year': 2024, 'experience_level': 'SE', 'employment_type': 'FT', 'job_title': 'Data Architect', 'salary': 117000, 'salary_currency': 'USD', 'salary_in_usd': 117000, 'employee_residence': 'US', 'remote_ratio': 0, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc662263f'), 'work_year': 2024, 'experience_level': 'SE', 'employment_type': 'FT', 'job_title': 'Data Analyst', 'salary': 117000, 'salary_currency': 'USD', 'salary_in_usd': 117000, 'employee_residence': 'US', 'remote_ratio': 100, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc6622640'), 'work_year': 2023, 'experience_level': 'MI', 'employment_type': 'FT', 'job_title': 'Data Engineer', 'salary': 117000, 'salary_currency': 'USD', 'salary_in_usd': 117000, 'employee_residence': 'US', 'remote_ratio': 0, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc6622641'), 'work_year': 2023, 'experience_level': 'SE', 'employment_type': 'FT', 'job_title': 'Data Architect', 'salary': 117000, 'salary_currency': 'USD', 'salary_in_usd': 117000, 'employee_residence': 'US', 'remote_ratio': 0, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc6622642'), 'work_year': 2023, 'experience_level': 'SE', 'employment_type': 'FT', 'job_title': 'Data Engineer', 'salary': 117000, 'salary_currency': 'USD', 'salary_in_usd': 117000, 'employee_residence': 'US', 'remote_ratio': 0, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc6622643'), 'work_year': 2023, 'experience_level': 'SE', 'employment_type': 'FT', 'job_title': 'Data Scientist', 'salary': 117000, 'salary_currency': 'USD', 'salary_in_usd': 117000, 'employee_residence': 'US', 'remote_ratio': 0, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc6622644'), 'work_year': 2023, 'experience_level': 'MI', 'employment_type': 'FT', 'job_title': 'Data Scientist', 'salary': 117000, 'salary_currency': 'USD', 'salary_in_usd': 117000, 'employee_residence': 'US', 'remote_ratio': 100, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc6622645'), 'work_year': 2023, 'experience_level': 'SE', 'employment_type': 'FT', 'job_title': 'Data Engineer', 'salary': 117000, 'salary_currency': 'CAD', 'salary_in_usd': 86682, 'employee_residence': 'CA', 'remote_ratio': 100, 'company_location': 'CA', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc6622646'), 'work_year': 2023, 'experience_level': 'SE', 'employment_type': 'FT', 'job_title': 'Data Architect', 'salary': 117000, 'salary_currency': 'USD', 'salary_in_usd': 117000, 'employee_residence': 'US', 'remote_ratio': 100, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc6622647'), 'work_year': 2023, 'experience_level': 'SE', 'employment_type': 'FT', 'job_title': 'Data Architect', 'salary': 117000, 'salary_currency': 'USD', 'salary_in_usd': 117000, 'employee_residence': 'US', 'remote_ratio': 100, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc6622648'), 'work_year': 2022, 'experience_level': 'SE', 'employment_type': 'FT', 'job_title': 'Data Engineer', 'salary': 117000, 'salary_currency': 'USD', 'salary_in_usd': 117000, 'employee_residence': 'US', 'remote_ratio': 0, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc6622649'), 'work_year': 2022, 'experience_level': 'SE', 'employment_type': 'FT', 'job_title': 'Data Analyst', 'salary': 117000, 'salary_currency': 'USD', 'salary_in_usd': 117000, 'employee_residence': 'US', 'remote_ratio': 100, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc662264a'), 'work_year': 2022, 'experience_level': 'SE', 'employment_type': 'FT', 'job_title': 'Data Analyst', 'salary': 117000, 'salary_currency': 'USD', 'salary_in_usd': 117000, 'employee_residence': 'US', 'remote_ratio': 100, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc662264b'), 'work_year': 2023, 'experience_level': 'SE', 'employment_type': 'FT', 'job_title': 'Analytics Engineer', 'salary': 116990, 'salary_currency': 'USD', 'salary_in_usd': 116990, 'employee_residence': 'US', 'remote_ratio': 100, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc662264c'), 'work_year': 2023, 'experience_level': 'MI', 'employment_type': 'FT', 'job_title': 'Data Scientist', 'salary': 116990, 'salary_currency': 'USD', 'salary_in_usd': 116990, 'employee_residence': 'US', 'remote_ratio': 100, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc662264d'), 'work_year': 2024, 'experience_level': 'SE', 'employment_type': 'FT', 'job_title': 'Data Scientist', 'salary': 116974, 'salary_currency': 'USD', 'salary_in_usd': 116974, 'employee_residence': 'US', 'remote_ratio': 0, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc662264e'), 'work_year': 2023, 'experience_level': 'SE', 'employment_type': 'FT', 'job_title': 'Data Analyst', 'salary': 116960, 'salary_currency': 'USD', 'salary_in_usd': 116960, 'employee_residence': 'US', 'remote_ratio': 0, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc662264f'), 'work_year': 2024, 'experience_level': 'SE', 'employment_type': 'FT', 'job_title': 'Data Analyst', 'salary': 116800, 'salary_currency': 'USD', 'salary_in_usd': 116800, 'employee_residence': 'US', 'remote_ratio': 0, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc6622650'), 'work_year': 2023, 'experience_level': 'MI', 'employment_type': 'FT', 'job_title': 'Machine Learning Engineer', 'salary': 116800, 'salary_currency': 'USD', 'salary_in_usd': 116800, 'employee_residence': 'US', 'remote_ratio': 0, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc6622651'), 'work_year': 2023, 'experience_level': 'SE', 'employment_type': 'FT', 'job_title': 'Analytics Engineer', 'salary': 116710, 'salary_currency': 'USD', 'salary_in_usd': 116710, 'employee_residence': 'US', 'remote_ratio': 100, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc6622652'), 'work_year': 2023, 'experience_level': 'EX', 'employment_type': 'FT', 'job_title': 'Data Engineer', 'salary': 116704, 'salary_currency': 'USD', 'salary_in_usd': 116704, 'employee_residence': 'US', 'remote_ratio': 100, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc6622653'), 'work_year': 2023, 'experience_level': 'EX', 'employment_type': 'FT', 'job_title': 'Data Engineer', 'salary': 116704, 'salary_currency': 'USD', 'salary_in_usd': 116704, 'employee_residence': 'US', 'remote_ratio': 100, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc6622654'), 'work_year': 2023, 'experience_level': 'SE', 'employment_type': 'FT', 'job_title': 'Data Analyst', 'salary': 116700, 'salary_currency': 'USD', 'salary_in_usd': 116700, 'employee_residence': 'US', 'remote_ratio': 0, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc6622655'), 'work_year': 2023, 'experience_level': 'MI', 'employment_type': 'FT', 'job_title': 'Data Analyst', 'salary': 116700, 'salary_currency': 'USD', 'salary_in_usd': 116700, 'employee_residence': 'US', 'remote_ratio': 0, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc6622656'), 'work_year': 2024, 'experience_level': 'SE', 'employment_type': 'FT', 'job_title': 'Data Engineer', 'salary': 116600, 'salary_currency': 'USD', 'salary_in_usd': 116600, 'employee_residence': 'US', 'remote_ratio': 100, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc6622657'), 'work_year': 2024, 'experience_level': 'MI', 'employment_type': 'FT', 'job_title': 'Analytics Engineer', 'salary': 116550, 'salary_currency': 'USD', 'salary_in_usd': 116550, 'employee_residence': 'US', 'remote_ratio': 0, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc6622658'), 'work_year': 2024, 'experience_level': 'SE', 'employment_type': 'FT', 'job_title': 'Data Management Specialist', 'salary': 116500, 'salary_currency': 'USD', 'salary_in_usd': 116500, 'employee_residence': 'US', 'remote_ratio': 0, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc6622659'), 'work_year': 2023, 'experience_level': 'SE', 'employment_type': 'FT', 'job_title': 'Data Engineer', 'salary': 116500, 'salary_currency': 'USD', 'salary_in_usd': 116500, 'employee_residence': 'US', 'remote_ratio': 100, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc662265a'), 'work_year': 2023, 'experience_level': 'MI', 'employment_type': 'FT', 'job_title': 'Data Engineer', 'salary': 116500, 'salary_currency': 'USD', 'salary_in_usd': 116500, 'employee_residence': 'US', 'remote_ratio': 100, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc662265b'), 'work_year': 2023, 'experience_level': 'MI', 'employment_type': 'FT', 'job_title': 'Analytics Engineer', 'salary': 116480, 'salary_currency': 'USD', 'salary_in_usd': 116480, 'employee_residence': 'US', 'remote_ratio': 0, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc662265c'), 'work_year': 2023, 'experience_level': 'SE', 'employment_type': 'FT', 'job_title': 'Data Engineer', 'salary': 116455, 'salary_currency': 'USD', 'salary_in_usd': 116455, 'employee_residence': 'US', 'remote_ratio': 0, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc662265d'), 'work_year': 2023, 'experience_level': 'SE', 'employment_type': 'FT', 'job_title': 'Analytics Engineer', 'salary': 116450, 'salary_currency': 'USD', 'salary_in_usd': 116450, 'employee_residence': 'US', 'remote_ratio': 0, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc662265e'), 'work_year': 2023, 'experience_level': 'SE', 'employment_type': 'FT', 'job_title': 'Business Intelligence Engineer', 'salary': 116300, 'salary_currency': 'USD', 'salary_in_usd': 116300, 'employee_residence': 'US', 'remote_ratio': 100, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc662265f'), 'work_year': 2023, 'experience_level': 'SE', 'employment_type': 'FT', 'job_title': 'Data Scientist', 'salary': 116300, 'salary_currency': 'USD', 'salary_in_usd': 116300, 'employee_residence': 'US', 'remote_ratio': 0, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc6622660'), 'work_year': 2023, 'experience_level': 'SE', 'employment_type': 'FT', 'job_title': 'Data Scientist', 'salary': 116300, 'salary_currency': 'USD', 'salary_in_usd': 116300, 'employee_residence': 'US', 'remote_ratio': 0, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc6622661'), 'work_year': 2024, 'experience_level': 'MI', 'employment_type': 'FT', 'job_title': 'Data Scientist', 'salary': 116259, 'salary_currency': 'USD', 'salary_in_usd': 116259, 'employee_residence': 'AU', 'remote_ratio': 0, 'company_location': 'AU', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc6622662'), 'work_year': 2022, 'experience_level': 'SE', 'employment_type': 'FT', 'job_title': 'Analytics Engineer', 'salary': 116250, 'salary_currency': 'USD', 'salary_in_usd': 116250, 'employee_residence': 'US', 'remote_ratio': 100, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc6622663'), 'work_year': 2022, 'experience_level': 'SE', 'employment_type': 'FT', 'job_title': 'Data Engineer', 'salary': 116250, 'salary_currency': 'USD', 'salary_in_usd': 116250, 'employee_residence': 'US', 'remote_ratio': 100, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc6622664'), 'work_year': 2024, 'experience_level': 'MI', 'employment_type': 'FT', 'job_title': 'Data Engineer', 'salary': 116200, 'salary_currency': 'USD', 'salary_in_usd': 116200, 'employee_residence': 'US', 'remote_ratio': 0, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc6622665'), 'work_year': 2024, 'experience_level': 'SE', 'employment_type': 'FT', 'job_title': 'Data Architect', 'salary': 116200, 'salary_currency': 'USD', 'salary_in_usd': 116200, 'employee_residence': 'US', 'remote_ratio': 0, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc6622666'), 'work_year': 2023, 'experience_level': 'MI', 'employment_type': 'FT', 'job_title': 'Data Analytics Manager', 'salary': 116200, 'salary_currency': 'USD', 'salary_in_usd': 116200, 'employee_residence': 'US', 'remote_ratio': 0, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc6622667'), 'work_year': 2022, 'experience_level': 'SE', 'employment_type': 'FT', 'job_title': 'Data Analyst', 'salary': 116150, 'salary_currency': 'USD', 'salary_in_usd': 116150, 'employee_residence': 'US', 'remote_ratio': 100, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc6622668'), 'work_year': 2022, 'experience_level': 'SE', 'employment_type': 'FT', 'job_title': 'Machine Learning Engineer', 'salary': 116100, 'salary_currency': 'USD', 'salary_in_usd': 116100, 'employee_residence': 'CA', 'remote_ratio': 100, 'company_location': 'CA', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc6622669'), 'work_year': 2022, 'experience_level': 'EX', 'employment_type': 'FT', 'job_title': 'Data Engineer', 'salary': 116100, 'salary_currency': 'USD', 'salary_in_usd': 116100, 'employee_residence': 'US', 'remote_ratio': 100, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc662266a'), 'work_year': 2024, 'experience_level': 'MI', 'employment_type': 'FT', 'job_title': 'Data Engineer', 'salary': 116047, 'salary_currency': 'USD', 'salary_in_usd': 116047, 'employee_residence': 'CA', 'remote_ratio': 0, 'company_location': 'CA', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc662266b'), 'work_year': 2024, 'experience_level': 'EN', 'employment_type': 'FT', 'job_title': 'Data Analyst', 'salary': 116013, 'salary_currency': 'USD', 'salary_in_usd': 116013, 'employee_residence': 'US', 'remote_ratio': 0, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc662266c'), 'work_year': 2024, 'experience_level': 'MI', 'employment_type': 'FT', 'job_title': 'Data Scientist', 'salary': 116000, 'salary_currency': 'USD', 'salary_in_usd': 116000, 'employee_residence': 'US', 'remote_ratio': 0, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc662266d'), 'work_year': 2024, 'experience_level': 'SE', 'employment_type': 'FT', 'job_title': 'Data Science Consultant', 'salary': 116000, 'salary_currency': 'USD', 'salary_in_usd': 116000, 'employee_residence': 'US', 'remote_ratio': 0, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc662266e'), 'work_year': 2024, 'experience_level': 'EN', 'employment_type': 'FT', 'job_title': 'Research Analyst', 'salary': 116000, 'salary_currency': 'USD', 'salary_in_usd': 116000, 'employee_residence': 'US', 'remote_ratio': 100, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc662266f'), 'work_year': 2024, 'experience_level': 'SE', 'employment_type': 'FT', 'job_title': 'Data Science Consultant', 'salary': 116000, 'salary_currency': 'USD', 'salary_in_usd': 116000, 'employee_residence': 'US', 'remote_ratio': 0, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc6622670'), 'work_year': 2024, 'experience_level': 'SE', 'employment_type': 'FT', 'job_title': 'Data Scientist', 'salary': 116000, 'salary_currency': 'USD', 'salary_in_usd': 116000, 'employee_residence': 'US', 'remote_ratio': 100, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc6622671'), 'work_year': 2024, 'experience_level': 'SE', 'employment_type': 'FT', 'job_title': 'Data Analyst', 'salary': 116000, 'salary_currency': 'USD', 'salary_in_usd': 116000, 'employee_residence': 'US', 'remote_ratio': 100, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc6622672'), 'work_year': 2024, 'experience_level': 'SE', 'employment_type': 'FT', 'job_title': 'Data Science', 'salary': 116000, 'salary_currency': 'USD', 'salary_in_usd': 116000, 'employee_residence': 'US', 'remote_ratio': 0, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc6622673'), 'work_year': 2024, 'experience_level': 'MI', 'employment_type': 'FT', 'job_title': 'Data Engineer', 'salary': 116000, 'salary_currency': 'USD', 'salary_in_usd': 116000, 'employee_residence': 'US', 'remote_ratio': 0, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc6622674'), 'work_year': 2024, 'experience_level': 'SE', 'employment_type': 'FT', 'job_title': 'Data Engineer', 'salary': 116000, 'salary_currency': 'USD', 'salary_in_usd': 116000, 'employee_residence': 'US', 'remote_ratio': 0, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc6622675'), 'work_year': 2023, 'experience_level': 'SE', 'employment_type': 'FT', 'job_title': 'Data Science Consultant', 'salary': 116000, 'salary_currency': 'USD', 'salary_in_usd': 116000, 'employee_residence': 'US', 'remote_ratio': 0, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc6622676'), 'work_year': 2023, 'experience_level': 'SE', 'employment_type': 'FT', 'job_title': 'Data Analyst', 'salary': 116000, 'salary_currency': 'USD', 'salary_in_usd': 116000, 'employee_residence': 'US', 'remote_ratio': 0, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc6622677'), 'work_year': 2023, 'experience_level': 'SE', 'employment_type': 'FT', 'job_title': 'Data Engineer', 'salary': 116000, 'salary_currency': 'USD', 'salary_in_usd': 116000, 'employee_residence': 'US', 'remote_ratio': 100, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc6622678'), 'work_year': 2023, 'experience_level': 'SE', 'employment_type': 'FT', 'job_title': 'Data Science Consultant', 'salary': 116000, 'salary_currency': 'USD', 'salary_in_usd': 116000, 'employee_residence': 'US', 'remote_ratio': 0, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc6622679'), 'work_year': 2023, 'experience_level': 'MI', 'employment_type': 'FT', 'job_title': 'Data Scientist', 'salary': 116000, 'salary_currency': 'USD', 'salary_in_usd': 116000, 'employee_residence': 'US', 'remote_ratio': 0, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc662267a'), 'work_year': 2023, 'experience_level': 'SE', 'employment_type': 'FT', 'job_title': 'Data Scientist', 'salary': 116000, 'salary_currency': 'USD', 'salary_in_usd': 116000, 'employee_residence': 'US', 'remote_ratio': 0, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc662267b'), 'work_year': 2023, 'experience_level': 'SE', 'employment_type': 'FT', 'job_title': 'Data Science Consultant', 'salary': 116000, 'salary_currency': 'USD', 'salary_in_usd': 116000, 'employee_residence': 'US', 'remote_ratio': 0, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc662267c'), 'work_year': 2023, 'experience_level': 'EN', 'employment_type': 'FT', 'job_title': 'Data Analyst', 'salary': 116000, 'salary_currency': 'USD', 'salary_in_usd': 116000, 'employee_residence': 'US', 'remote_ratio': 0, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc662267d'), 'work_year': 2023, 'experience_level': 'SE', 'employment_type': 'FT', 'job_title': 'Data Science Consultant', 'salary': 116000, 'salary_currency': 'USD', 'salary_in_usd': 116000, 'employee_residence': 'US', 'remote_ratio': 0, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc662267e'), 'work_year': 2023, 'experience_level': 'SE', 'employment_type': 'FT', 'job_title': 'Analytics Engineer', 'salary': 116000, 'salary_currency': 'USD', 'salary_in_usd': 116000, 'employee_residence': 'US', 'remote_ratio': 100, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc662267f'), 'work_year': 2023, 'experience_level': 'SE', 'employment_type': 'FT', 'job_title': 'Data Engineer', 'salary': 116000, 'salary_currency': 'USD', 'salary_in_usd': 116000, 'employee_residence': 'US', 'remote_ratio': 0, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc6622680'), 'work_year': 2023, 'experience_level': 'SE', 'employment_type': 'FT', 'job_title': 'Data Analyst', 'salary': 116000, 'salary_currency': 'USD', 'salary_in_usd': 116000, 'employee_residence': 'US', 'remote_ratio': 100, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc6622681'), 'work_year': 2023, 'experience_level': 'MI', 'employment_type': 'FT', 'job_title': 'Data Engineer', 'salary': 116000, 'salary_currency': 'USD', 'salary_in_usd': 116000, 'employee_residence': 'US', 'remote_ratio': 0, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc6622682'), 'work_year': 2023, 'experience_level': 'SE', 'employment_type': 'FT', 'job_title': 'Data Engineer', 'salary': 116000, 'salary_currency': 'USD', 'salary_in_usd': 116000, 'employee_residence': 'US', 'remote_ratio': 0, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc6622683'), 'work_year': 2023, 'experience_level': 'MI', 'employment_type': 'FT', 'job_title': 'Data Analyst', 'salary': 116000, 'salary_currency': 'USD', 'salary_in_usd': 116000, 'employee_residence': 'US', 'remote_ratio': 0, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc6622684'), 'work_year': 2022, 'experience_level': 'SE', 'employment_type': 'FT', 'job_title': 'Data Analyst', 'salary': 116000, 'salary_currency': 'USD', 'salary_in_usd': 116000, 'employee_residence': 'US', 'remote_ratio': 100, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc6622685'), 'work_year': 2022, 'experience_level': 'SE', 'employment_type': 'FT', 'job_title': 'Data Analyst', 'salary': 116000, 'salary_currency': 'USD', 'salary_in_usd': 116000, 'employee_residence': 'US', 'remote_ratio': 0, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc6622686'), 'work_year': 2023, 'experience_level': 'MI', 'employment_type': 'FT', 'job_title': 'Data Analyst', 'salary': 115950, 'salary_currency': 'USD', 'salary_in_usd': 115950, 'employee_residence': 'US', 'remote_ratio': 0, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc6622687'), 'work_year': 2023, 'experience_level': 'MI', 'employment_type': 'FT', 'job_title': 'Data Analyst', 'salary': 115950, 'salary_currency': 'USD', 'salary_in_usd': 115950, 'employee_residence': 'US', 'remote_ratio': 0, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc6622688'), 'work_year': 2023, 'experience_level': 'SE', 'employment_type': 'FT', 'job_title': 'Data Analyst', 'salary': 115934, 'salary_currency': 'USD', 'salary_in_usd': 115934, 'employee_residence': 'US', 'remote_ratio': 100, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc6622689'), 'work_year': 2023, 'experience_level': 'SE', 'employment_type': 'FT', 'job_title': 'Data Analyst', 'salary': 115934, 'salary_currency': 'USD', 'salary_in_usd': 115934, 'employee_residence': 'US', 'remote_ratio': 100, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc662268a'), 'work_year': 2023, 'experience_level': 'SE', 'employment_type': 'FT', 'job_title': 'Data Analyst', 'salary': 115934, 'salary_currency': 'USD', 'salary_in_usd': 115934, 'employee_residence': 'US', 'remote_ratio': 100, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc662268b'), 'work_year': 2023, 'experience_level': 'SE', 'employment_type': 'FT', 'job_title': 'Data Analyst', 'salary': 115934, 'salary_currency': 'USD', 'salary_in_usd': 115934, 'employee_residence': 'US', 'remote_ratio': 100, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc662268c'), 'work_year': 2022, 'experience_level': 'SE', 'employment_type': 'FT', 'job_title': 'Data Analyst', 'salary': 115934, 'salary_currency': 'USD', 'salary_in_usd': 115934, 'employee_residence': 'US', 'remote_ratio': 100, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc662268d'), 'work_year': 2022, 'experience_level': 'SE', 'employment_type': 'FT', 'job_title': 'Data Analyst', 'salary': 115934, 'salary_currency': 'USD', 'salary_in_usd': 115934, 'employee_residence': 'US', 'remote_ratio': 100, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc662268e'), 'work_year': 2022, 'experience_level': 'SE', 'employment_type': 'FT', 'job_title': 'Data Analyst', 'salary': 115934, 'salary_currency': 'USD', 'salary_in_usd': 115934, 'employee_residence': 'US', 'remote_ratio': 100, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc662268f'), 'work_year': 2022, 'experience_level': 'SE', 'employment_type': 'FT', 'job_title': 'Data Analyst', 'salary': 115934, 'salary_currency': 'USD', 'salary_in_usd': 115934, 'employee_residence': 'US', 'remote_ratio': 100, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc6622690'), 'work_year': 2022, 'experience_level': 'SE', 'employment_type': 'FT', 'job_title': 'Data Analyst', 'salary': 115934, 'salary_currency': 'USD', 'salary_in_usd': 115934, 'employee_residence': 'US', 'remote_ratio': 100, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc6622691'), 'work_year': 2022, 'experience_level': 'SE', 'employment_type': 'FT', 'job_title': 'Data Analyst', 'salary': 115934, 'salary_currency': 'USD', 'salary_in_usd': 115934, 'employee_residence': 'US', 'remote_ratio': 0, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc6622692'), 'work_year': 2022, 'experience_level': 'SE', 'employment_type': 'FT', 'job_title': 'Data Analyst', 'salary': 115934, 'salary_currency': 'USD', 'salary_in_usd': 115934, 'employee_residence': 'US', 'remote_ratio': 100, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc6622693'), 'work_year': 2023, 'experience_level': 'SE', 'employment_type': 'FT', 'job_title': 'Data Analytics Lead', 'salary': 115920, 'salary_currency': 'USD', 'salary_in_usd': 115920, 'employee_residence': 'US', 'remote_ratio': 0, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc6622694'), 'work_year': 2023, 'experience_level': 'SE', 'employment_type': 'FT', 'job_title': 'Data Scientist', 'salary': 115920, 'salary_currency': 'USD', 'salary_in_usd': 115920, 'employee_residence': 'US', 'remote_ratio': 0, 'company_location': 'US', 'company_size': 'M'}
# ...
# {'_id': ObjectId('671e402d1c2b687bc6623951'), 'work_year': 2022, 'experience_level': 'MI', 'employment_type': 'FT', 'job_title': 'Data Engineer', 'salary': 24000, 'salary_currency': 'USD', 'salary_in_usd': 24000, 'employee_residence': 'US', 'remote_ratio': 0, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc6623952'), 'work_year': 2021, 'experience_level': 'SE', 'employment_type': 'FT', 'job_title': 'Computer Vision Engineer', 'salary': 24000, 'salary_currency': 'USD', 'salary_in_usd': 24000, 'employee_residence': 'BR', 'remote_ratio': 100, 'company_location': 'BR', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc6623953'), 'work_year': 2021, 'experience_level': 'MI', 'employment_type': 'FT', 'job_title': 'Data Engineer', 'salary': 24000, 'salary_currency': 'EUR', 'salary_in_usd': 28369, 'employee_residence': 'MT', 'remote_ratio': 50, 'company_location': 'MT', 'company_size': 'L'}
# {'_id': ObjectId('671e402d1c2b687bc6623954'), 'work_year': 2023, 'experience_level': 'EN', 'employment_type': 'FT', 'job_title': 'AI Research Engineer', 'salary': 23100, 'salary_currency': 'EUR', 'salary_in_usd': 24940, 'employee_residence': 'PT', 'remote_ratio': 100, 'company_location': 'PT', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc6623955'), 'work_year': 2024, 'experience_level': 'EN', 'employment_type': 'FT', 'job_title': 'Data Analyst', 'salary': 23000, 'salary_currency': 'GBP', 'salary_in_usd': 28750, 'employee_residence': 'GB', 'remote_ratio': 0, 'company_location': 'GB', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc6623956'), 'work_year': 2024, 'experience_level': 'EN', 'employment_type': 'FT', 'job_title': 'Data Analyst', 'salary': 23000, 'salary_currency': 'GBP', 'salary_in_usd': 28750, 'employee_residence': 'GB', 'remote_ratio': 0, 'company_location': 'GB', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc6623957'), 'work_year': 2024, 'experience_level': 'EN', 'employment_type': 'FT', 'job_title': 'Data Analyst', 'salary': 23000, 'salary_currency': 'GBP', 'salary_in_usd': 28750, 'employee_residence': 'GB', 'remote_ratio': 0, 'company_location': 'GB', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc6623958'), 'work_year': 2024, 'experience_level': 'EN', 'employment_type': 'FT', 'job_title': 'Data Analyst', 'salary': 23000, 'salary_currency': 'GBP', 'salary_in_usd': 28750, 'employee_residence': 'GB', 'remote_ratio': 0, 'company_location': 'GB', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc6623959'), 'work_year': 2023, 'experience_level': 'EN', 'employment_type': 'FT', 'job_title': 'Data Analyst', 'salary': 23000, 'salary_currency': 'GBP', 'salary_in_usd': 28299, 'employee_residence': 'GB', 'remote_ratio': 0, 'company_location': 'GB', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc662395a'), 'work_year': 2023, 'experience_level': 'EN', 'employment_type': 'FT', 'job_title': 'Data Analyst', 'salary': 23000, 'salary_currency': 'GBP', 'salary_in_usd': 28299, 'employee_residence': 'GB', 'remote_ratio': 0, 'company_location': 'GB', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc662395b'), 'work_year': 2022, 'experience_level': 'MI', 'employment_type': 'FT', 'job_title': 'Research Scientist', 'salary': 23000, 'salary_currency': 'USD', 'salary_in_usd': 23000, 'employee_residence': 'IN', 'remote_ratio': 100, 'company_location': 'IN', 'company_size': 'L'}
# {'_id': ObjectId('671e402d1c2b687bc662395c'), 'work_year': 2022, 'experience_level': 'EN', 'employment_type': 'FT', 'job_title': 'Data Science Consultant', 'salary': 23000, 'salary_currency': 'EUR', 'salary_in_usd': 24165, 'employee_residence': 'IT', 'remote_ratio': 50, 'company_location': 'IT', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc662395d'), 'work_year': 2022, 'experience_level': 'MI', 'employment_type': 'FT', 'job_title': 'Machine Learning Scientist', 'salary': 22800, 'salary_currency': 'USD', 'salary_in_usd': 22800, 'employee_residence': 'EG', 'remote_ratio': 100, 'company_location': 'EG', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc662395e'), 'work_year': 2023, 'experience_level': 'EN', 'employment_type': 'FT', 'job_title': 'Data Quality Engineer', 'salary': 22000, 'salary_currency': 'EUR', 'salary_in_usd': 23753, 'employee_residence': 'PT', 'remote_ratio': 50, 'company_location': 'PT', 'company_size': 'L'}
# {'_id': ObjectId('671e402d1c2b687bc662395f'), 'work_year': 2021, 'experience_level': 'MI', 'employment_type': 'FT', 'job_title': 'Data Engineer', 'salary': 22000, 'salary_currency': 'EUR', 'salary_in_usd': 26005, 'employee_residence': 'RO', 'remote_ratio': 0, 'company_location': 'US', 'company_size': 'L'}
# {'_id': ObjectId('671e402d1c2b687bc6623960'), 'work_year': 2021, 'experience_level': 'EN', 'employment_type': 'FT', 'job_title': 'Machine Learning Engineer', 'salary': 21844, 'salary_currency': 'USD', 'salary_in_usd': 21844, 'employee_residence': 'CO', 'remote_ratio': 50, 'company_location': 'CO', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc6623961'), 'work_year': 2024, 'experience_level': 'SE', 'employment_type': 'FT', 'job_title': 'BI Developer', 'salary': 21600, 'salary_currency': 'USD', 'salary_in_usd': 21600, 'employee_residence': 'PH', 'remote_ratio': 0, 'company_location': 'PH', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc6623962'), 'work_year': 2021, 'experience_level': 'MI', 'employment_type': 'FT', 'job_title': 'Data Scientist', 'salary': 21600, 'salary_currency': 'EUR', 'salary_in_usd': 25532, 'employee_residence': 'RS', 'remote_ratio': 100, 'company_location': 'DE', 'company_size': 'S'}
# {'_id': ObjectId('671e402d1c2b687bc6623963'), 'work_year': 2024, 'experience_level': 'EN', 'employment_type': 'FT', 'job_title': 'Data Analyst', 'salary': 21000, 'salary_currency': 'EUR', 'salary_in_usd': 23333, 'employee_residence': 'ES', 'remote_ratio': 0, 'company_location': 'ES', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc6623964'), 'work_year': 2023, 'experience_level': 'MI', 'employment_type': 'FL', 'job_title': 'Data Science Consultant', 'salary': 21000, 'salary_currency': 'USD', 'salary_in_usd': 21000, 'employee_residence': 'PK', 'remote_ratio': 100, 'company_location': 'LU', 'company_size': 'S'}
# {'_id': ObjectId('671e402d1c2b687bc6623965'), 'work_year': 2021, 'experience_level': 'EN', 'employment_type': 'FT', 'job_title': 'Machine Learning Engineer', 'salary': 21000, 'salary_currency': 'EUR', 'salary_in_usd': 24823, 'employee_residence': 'DE', 'remote_ratio': 50, 'company_location': 'DE', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc6623966'), 'work_year': 2021, 'experience_level': 'MI', 'employment_type': 'FT', 'job_title': 'Machine Learning Engineer', 'salary': 21000, 'salary_currency': 'EUR', 'salary_in_usd': 24823, 'employee_residence': 'SI', 'remote_ratio': 50, 'company_location': 'SI', 'company_size': 'L'}
# {'_id': ObjectId('671e402d1c2b687bc6623967'), 'work_year': 2023, 'experience_level': 'EN', 'employment_type': 'FT', 'job_title': 'AI Engineer', 'salary': 20000, 'salary_currency': 'EUR', 'salary_in_usd': 21593, 'employee_residence': 'PT', 'remote_ratio': 50, 'company_location': 'PT', 'company_size': 'L'}
# {'_id': ObjectId('671e402d1c2b687bc6623968'), 'work_year': 2023, 'experience_level': 'EN', 'employment_type': 'FT', 'job_title': 'AI Scientist', 'salary': 20000, 'salary_currency': 'USD', 'salary_in_usd': 20000, 'employee_residence': 'TR', 'remote_ratio': 100, 'company_location': 'TR', 'company_size': 'S'}
# {'_id': ObjectId('671e402d1c2b687bc6623969'), 'work_year': 2023, 'experience_level': 'MI', 'employment_type': 'FT', 'job_title': 'Applied Scientist', 'salary': 20000, 'salary_currency': 'USD', 'salary_in_usd': 20000, 'employee_residence': 'NG', 'remote_ratio': 100, 'company_location': 'US', 'company_size': 'L'}
# {'_id': ObjectId('671e402d1c2b687bc662396a'), 'work_year': 2023, 'experience_level': 'EN', 'employment_type': 'FT', 'job_title': 'Business Data Analyst', 'salary': 20000, 'salary_currency': 'EUR', 'salary_in_usd': 21593, 'employee_residence': 'ES', 'remote_ratio': 0, 'company_location': 'ES', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc662396b'), 'work_year': 2022, 'experience_level': 'EN', 'employment_type': 'FT', 'job_title': 'Data Analyst', 'salary': 20000, 'salary_currency': 'USD', 'salary_in_usd': 20000, 'employee_residence': 'CR', 'remote_ratio': 50, 'company_location': 'US', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc662396c'), 'work_year': 2021, 'experience_level': 'EN', 'employment_type': 'FT', 'job_title': 'Machine Learning Research Engineer', 'salary': 20000, 'salary_currency': 'USD', 'salary_in_usd': 20000, 'employee_residence': 'FR', 'remote_ratio': 50, 'company_location': 'FR', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc662396d'), 'work_year': 2020, 'experience_level': 'EN', 'employment_type': 'FT', 'job_title': 'Data Analyst', 'salary': 20000, 'salary_currency': 'EUR', 'salary_in_usd': 22809, 'employee_residence': 'PT', 'remote_ratio': 100, 'company_location': 'PT', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc662396e'), 'work_year': 2022, 'experience_level': 'MI', 'employment_type': 'FT', 'job_title': 'Data Analyst', 'salary': 20000, 'salary_currency': 'USD', 'salary_in_usd': 20000, 'employee_residence': 'GR', 'remote_ratio': 100, 'company_location': 'GR', 'company_size': 'S'}
# {'_id': ObjectId('671e402d1c2b687bc662396f'), 'work_year': 2020, 'experience_level': 'MI', 'employment_type': 'FT', 'job_title': 'Product Data Analyst', 'salary': 20000, 'salary_currency': 'USD', 'salary_in_usd': 20000, 'employee_residence': 'HN', 'remote_ratio': 0, 'company_location': 'HN', 'company_size': 'S'}
# {'_id': ObjectId('671e402d1c2b687bc6623970'), 'work_year': 2022, 'experience_level': 'EN', 'employment_type': 'FT', 'job_title': 'Data Analytics Engineer', 'salary': 20000, 'salary_currency': 'USD', 'salary_in_usd': 20000, 'employee_residence': 'PK', 'remote_ratio': 0, 'company_location': 'PK', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc6623971'), 'work_year': 2021, 'experience_level': 'EN', 'employment_type': 'FT', 'job_title': 'Machine Learning Engineer', 'salary': 20000, 'salary_currency': 'USD', 'salary_in_usd': 20000, 'employee_residence': 'IN', 'remote_ratio': 100, 'company_location': 'IN', 'company_size': 'S'}
# {'_id': ObjectId('671e402d1c2b687bc6623972'), 'work_year': 2022, 'experience_level': 'EN', 'employment_type': 'FT', 'job_title': 'ML Engineer', 'salary': 20000, 'salary_currency': 'EUR', 'salary_in_usd': 21013, 'employee_residence': 'PT', 'remote_ratio': 100, 'company_location': 'PT', 'company_size': 'L'}
# {'_id': ObjectId('671e402d1c2b687bc6623973'), 'work_year': 2021, 'experience_level': 'MI', 'employment_type': 'FL', 'job_title': 'Data Engineer', 'salary': 20000, 'salary_currency': 'USD', 'salary_in_usd': 20000, 'employee_residence': 'IT', 'remote_ratio': 0, 'company_location': 'US', 'company_size': 'L'}
# {'_id': ObjectId('671e402d1c2b687bc6623974'), 'work_year': 2020, 'experience_level': 'EN', 'employment_type': 'PT', 'job_title': 'Data Scientist', 'salary': 19000, 'salary_currency': 'EUR', 'salary_in_usd': 21669, 'employee_residence': 'IT', 'remote_ratio': 50, 'company_location': 'IT', 'company_size': 'S'}
# {'_id': ObjectId('671e402d1c2b687bc6623975'), 'work_year': 2023, 'experience_level': 'EN', 'employment_type': 'FT', 'job_title': 'Data Analyst Lead', 'salary': 18000, 'salary_currency': 'USD', 'salary_in_usd': 18000, 'employee_residence': 'NG', 'remote_ratio': 100, 'company_location': 'NG', 'company_size': 'S'}
# {'_id': ObjectId('671e402d1c2b687bc6623976'), 'work_year': 2023, 'experience_level': 'EN', 'employment_type': 'FT', 'job_title': 'Data Scientist', 'salary': 18000, 'salary_currency': 'EUR', 'salary_in_usd': 19434, 'employee_residence': 'GR', 'remote_ratio': 100, 'company_location': 'GR', 'company_size': 'L'}
# {'_id': ObjectId('671e402d1c2b687bc6623977'), 'work_year': 2023, 'experience_level': 'EN', 'employment_type': 'FT', 'job_title': 'Data Engineer', 'salary': 18000, 'salary_currency': 'USD', 'salary_in_usd': 18000, 'employee_residence': 'IN', 'remote_ratio': 50, 'company_location': 'IN', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc6623978'), 'work_year': 2021, 'experience_level': 'MI', 'employment_type': 'FT', 'job_title': 'Big Data Engineer', 'salary': 18000, 'salary_currency': 'USD', 'salary_in_usd': 18000, 'employee_residence': 'MD', 'remote_ratio': 0, 'company_location': 'MD', 'company_size': 'S'}
# {'_id': ObjectId('671e402d1c2b687bc6623979'), 'work_year': 2024, 'experience_level': 'EN', 'employment_type': 'FT', 'job_title': 'Big Data Engineer', 'salary': 17600, 'salary_currency': 'USD', 'salary_in_usd': 17600, 'employee_residence': 'MX', 'remote_ratio': 50, 'company_location': 'MX', 'company_size': 'L'}
# {'_id': ObjectId('671e402d1c2b687bc662397a'), 'work_year': 2024, 'experience_level': 'EN', 'employment_type': 'FT', 'job_title': 'Data Engineer', 'salary': 17598, 'salary_currency': 'USD', 'salary_in_usd': 17598, 'employee_residence': 'MX', 'remote_ratio': 50, 'company_location': 'MX', 'company_size': 'L'}
# {'_id': ObjectId('671e402d1c2b687bc662397b'), 'work_year': 2023, 'experience_level': 'MI', 'employment_type': 'FT', 'job_title': 'Business Data Analyst', 'salary': 17000, 'salary_currency': 'USD', 'salary_in_usd': 17000, 'employee_residence': 'AM', 'remote_ratio': 100, 'company_location': 'RU', 'company_size': 'L'}
# {'_id': ObjectId('671e402d1c2b687bc662397c'), 'work_year': 2023, 'experience_level': 'EN', 'employment_type': 'FT', 'job_title': 'Data Scientist', 'salary': 16000, 'salary_currency': 'USD', 'salary_in_usd': 16000, 'employee_residence': 'EC', 'remote_ratio': 100, 'company_location': 'EC', 'company_size': 'L'}
# {'_id': ObjectId('671e402d1c2b687bc662397d'), 'work_year': 2022, 'experience_level': 'EN', 'employment_type': 'FT', 'job_title': 'Research Engineer', 'salary': 15662, 'salary_currency': 'EUR', 'salary_in_usd': 16455, 'employee_residence': 'RU', 'remote_ratio': 100, 'company_location': 'RU', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc662397e'), 'work_year': 2024, 'experience_level': 'EN', 'employment_type': 'PT', 'job_title': 'Data Science', 'salary': 15000, 'salary_currency': 'EUR', 'salary_in_usd': 16666, 'employee_residence': 'DE', 'remote_ratio': 50, 'company_location': 'DE', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc662397f'), 'work_year': 2022, 'experience_level': 'MI', 'employment_type': 'FT', 'job_title': 'Business Intelligence Developer', 'salary': 15000, 'salary_currency': 'USD', 'salary_in_usd': 15000, 'employee_residence': 'GH', 'remote_ratio': 100, 'company_location': 'GH', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc6623980'), 'work_year': 2020, 'experience_level': 'EX', 'employment_type': 'FT', 'job_title': 'Staff Data Analyst', 'salary': 15000, 'salary_currency': 'USD', 'salary_in_usd': 15000, 'employee_residence': 'NG', 'remote_ratio': 0, 'company_location': 'CA', 'company_size': 'M'}
# {'_id': ObjectId('671e402d1c2b687bc6623981'), 'work_year': 2021, 'experience_level': 'EN', 'employment_type': 'FT', 'job_title': 'Machine Learning Developer', 'salary': 15000, 'salary_currency': 'USD', 'salary_in_usd': 15000, 'employee_residence': 'TH', 'remote_ratio': 100, 'company_location': 'TH', 'company_size': 'L'}
# {'_id': ObjectId('671e402d1c2b687bc6623982'), 'work_year': 2022, 'experience_level': 'EN', 'employment_type': 'FT', 'job_title': 'Data Analyst', 'salary': 15000, 'salary_currency': 'USD', 'salary_in_usd': 15000, 'employee_residence': 'ID', 'remote_ratio': 0, 'company_location': 'ID', 'company_size': 'L'}
# {'_id': ObjectId('671e402d1c2b687bc6623983'), 'work_year': 2020, 'experience_level': 'EN', 'employment_type': 'PT', 'job_title': 'ML Engineer', 'salary': 14000, 'salary_currency': 'EUR', 'salary_in_usd': 15966, 'employee_residence': 'DE', 'remote_ratio': 100, 'company_location': 'DE', 'company_size': 'S'}
